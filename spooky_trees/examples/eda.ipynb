# %%
import pandas as pd

# %%
X = pd.read_csv("/home/khaymonenko/trees-and-ensembles/data/competition/train.csv", index_col="Id")
X
# Out:
#       does-bruise-or-bleed habitat season  cap-diameter  stem-height  \
# Id
# 50051                    t       d      u          8.94         7.91
# 19596                    f       m      a          2.92         3.59
# 3645                     f       m      a          4.11         4.78
# 39079                    f       d      a          3.24         4.65
# 2245                     f       d      u          8.48        13.72
# ...                    ...     ...    ...           ...          ...
# 30503                    t       d      a          8.23         5.97
# 8328                     f       d      a          3.37         6.86
# 10273                    f       d      s          3.28         4.29
# 55086                    f       l      a          6.70         7.67
# 58892                    f       d      a         21.51         4.99
#
#        stem-width  class
# Id
# 50051       24.55      1
# 19596        6.59      1
# 3645         3.56      1
# ...

# %%
cat_columns = ["does-bruise-or-bleed", "habitat", "season"]
mappings = {}

for feature in cat_columns:
    mappings[feature] = {value: idx for idx, value in enumerate(X[feature].unique())}
    X[feature] = X[feature].map(mappings[feature])

X.to_numpy()
# Out:
# array([[ 0.  ,  0.  ,  0.  , ...,  7.91, 24.55,  1.  ],
#        [ 1.  ,  1.  ,  1.  , ...,  3.59,  6.59,  1.  ],
#        [ 1.  ,  1.  ,  1.  , ...,  4.78,  3.56,  1.  ],
#        ...,
#        [ 1.  ,  0.  ,  2.  , ...,  4.29,  2.64,  0.  ],
#        [ 1.  ,  4.  ,  1.  , ...,  7.67, 50.19,  0.  ],
#        [ 1.  ,  0.  ,  1.  , ...,  4.99, 37.01,  1.  ]])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_417478/785050874.py in ?()
# ----> 1 X.map(mappings)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'map'

# %%
X['habitat'].map(mappings['habitat'])
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 7495    0
# 7496    0
# 7497    0
# 7498    4
# 7499    0
# Name: habitat, Length: 7500, dtype: int64
